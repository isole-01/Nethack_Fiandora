# %%
ENV='MiniHack-KeyRoom-S15-v0'
# ENV='MiniHack-CorridorBattle-v0'
H = 10
W = 10
NUM_EPISODES = 1
MAX_STEPS = 450
PATH = 'kbkey.pl'

# %%
from utilsk import decide_next_cell_to_explore, initialize,perform_action,coordinates_to_actions,astar,obschar_to_mask, actions, positions,  process_state, show_match
from pyswip import Prolog
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
KB = Prolog()
KB.consult(PATH)

# %%
import gym
import minihack
import matplotlib.pyplot as plt
from minihack import LevelGenerator
from nle import nethack


# map = """
# --------------------------------------
# |....................................|
# |....................................|
# |....................................|
# |....................................|
# |....................................|
# |....................................|
# |....................................|
# ||||||||.|||||.......................|
# |............|.......................|
# |............|.......................|
# |............|.......................|
# |............|.......................|
# |............|.......................|
# --------------------------------------
# """

# lvl_gen = LevelGenerator(map=map, lit=True)
# lvl_gen.set_start_pos((3, 6))
# lvl_gen.add_door("closed", place=(8,8))
# lvl_gen.add_object(name='skeleton key', symbol='(', place=(28,7))
# lvl_gen.add_goal_pos((11, 10))

map = """
--------------------------------------
|....................................|
|..-----....|..|.............|.......|
|..|   |..--|--|-------...------.....|
|..--- |....|..|.....................|
|....| ||......||....-----......|....|
|....|  |-------.........|......|....|
|....|  |................|||..|||....|
------  |-------....------......|....|
        |......|................|..|||
        |......--------.........|....|
        |.............|---------|....|
        |............................|
        |.............|---------|....|
        ------------------------------ 
"""

lvl_gen = LevelGenerator(map=map, lit=False)
lvl_gen.set_start_pos((3, 6))
# lvl_gen.add_monster(name="giant rat", place=(10, 11))
# lvl_gen.add_monster(name="giant rat", place=(10, 12))
# lvl_gen.add_monster(name="giant rat", place=(10, 13))
# lvl_gen.add_monster(name="giant rat", place=(11, 11))
# lvl_gen.add_monster(name="giant rat", place=(11, 12))
# lvl_gen.add_monster(name="giant rat", place=(11, 13))
lvl_gen.add_door("closed", place=(32,12))
lvl_gen.add_object(name='skeleton key', symbol='(', place=(28,7))
lvl_gen.add_goal_pos((11, 10))

initialize()

MOVE_ACTIONS = tuple(nethack.CompassDirection)
NAVIGATE_ACTIONS = MOVE_ACTIONS + (
    nethack.Command.PICKUP,
    nethack.Command.OPEN
)

env = gym.make("MiniHack-Skill-Custom-v0",
               character="rog-hum-cha-mal",
               observation_keys=('screen_descriptions','chars','glyphs','inv_strs','blstats','message','pixel','pixel_crop'),
               des_file = lvl_gen.get_des(),
               max_episode_steps=600,
               actions = NAVIGATE_ACTIONS)
obs=env.reset() # each reset generates a new environment instance
env.render()
# Out:
# Hello Agent, welcome to NetHack!  You are a chaotic male human Rogue.
#
#
#
#
#
#
#
#
#                       ...
#                       .@.
#                       ...
#
#
#
#
#
#
#
#
#
#
# Agent the Footpad              St:14 Dx:18 Co:17 In:9 Wi:8 Ch:9 Chaotic S:0
# Dlvl:1 $:0 HP:12(12) Pw:2(2) AC:7 Xp:1/0

# %%
obs, reward, done, info=perform_action('east', env, KB,obs)
plt.imshow(obs['pixel_crop'])

# %%
process_state(obs, KB)
action = list(KB.query('standing_next(door)'))
action
# Out:
# []

# %%
front_location(obs,positions["door"][0],positions["door"][1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 front_location(obs,positions["door"][0],positions["door"][1])
#
# NameError: name 'front_location' is not defined

# %%
KB.retractall('standing_next(door)')

# %%
action = list(KB.query('action(X)'))[0]["X"]
action
# Out:
# 'explore'

# %%
b_cell=decide_next_cell_to_explore(obs)
agent_p=positions['agent']
masked=obschar_to_mask(obs)
# print(agent_p,b_cell)
path = astar(masked,agent_p, b_cell)
path.append(agent_p)
path.reverse()
navs = coordinates_to_actions(path)

# %%
b_cell
# Out:
# (15, 51)

# %%
navs
# Out:
# ['east']

# %%
positions["agent"], positions["door"]
# Out:
# ((15, 50), (15, 52))

# %%
rewards = []
performed_acts=[]

def run(obs,performed_acts):
    initialize()

    # count the number of steps of the current episode
    steps = 0
    # store the cumulative reward
    reward = 0.0
    # collect obs['pixel'] to visualize
    ep_states = []

    # obs = env.reset()
    ep_states.append(obs['pixel'])
    done = False
    info=None

    # Main loop
    plan=[]
    while not done and steps < MAX_STEPS:
        # Get the observation from the env and assert the facts in the kb 
        process_state(obs, KB)

        # Query Prolog
        # Run the inference and get the action to perform
        # Get the first answer from Prolog -> the top-priority action
       
        action = list(KB.query('action(X)'))[0]["X"]
      
        # print(f'>> Current action from Prolog: {action}')
        
        if action:
            navs=[]
            if 'go(stairs)' in action:
                agent_p=positions['agent']
                stairs_p=positions['stairs']
                masked=obschar_to_mask(obs)
                path = astar(masked,agent_p, stairs_p)
                path.append(agent_p)
                path.reverse()
                navs = coordinates_to_actions(path)

            elif 'enter(door)' in action:
                agent_p=positions['agent']
                door_p=positions['door']
                masked=obschar_to_mask(obs)
                path = astar(masked,agent_p, door_p)
                path.append(agent_p)
                path.reverse()
                navs = coordinates_to_actions(path)
                KB.retractall('standing_next(door)')

                
            elif 'opendoor' in action:
                obs, reward, done, info = perform_action("opendoor", env, KB,obs)
                performed_acts+=["opendoor"]
                steps += 1
                process_state(obs, KB)
                ep_states.append(obs['pixel'])
                env.render()
                
            elif "pick" in action:
                obs, reward, done, info = perform_action("pick", env, KB,obs)
                performed_acts+=["pick"]
                steps += 1
                process_state(obs, KB)
                ep_states.append(obs['pixel'])
                env.render()
                
            if "go(door)" in action:
                agent_p=positions['agent']
                door_p=positions['door_front']
                masked=obschar_to_mask(obs)
                path = astar(masked,agent_p, door_p)
                path.append(agent_p)
                path.reverse()
                navs = coordinates_to_actions(path)

                
            elif "go(key)" in action:
                agent_p=positions['agent']
                key_p=positions['key']
                masked=obschar_to_mask(obs)
                path = astar(masked,agent_p, key_p)
                path.append(agent_p)
                path.reverse()
                navs = coordinates_to_actions(path)
                
            elif 'explore' in action:
                b_cell=decide_next_cell_to_explore(obs)
                agent_p=positions['agent']
                masked=obschar_to_mask(obs)
                # print(agent_p,b_cell)
                path = astar(masked,agent_p, b_cell)
                path.append(agent_p)
                path.reverse()
                navs = coordinates_to_actions(path)

                
            for nav in navs:
                performed_acts+=[nav]

                process_state(obs, KB)

                if list(KB.query('action(X)'))[0]["X"] != action:
                    break
                    
                obs, reward, done, info = perform_action(nav, env, KB,obs)
                steps += 1
                process_state(obs, KB)
                ep_states.append(obs['pixel'])
                # env.render()
                
                

        else:
            print("ERROR: impossible to perform any action. Please check assertions and definitions in KB.")
            break


    # Display game with interface
    show_match(ep_states,0,600,250,1350)
    # show_match(ep_states,0,200,0,200)
    # Print information about the ended episode
    print(f'Episode {episode} - {steps} steps')
    print(f'End status: {info["end_status"].name}')
    print(f'Final reward: {reward}')
    time.sleep(0.75)

    # rewards.append(reward)

    # # reset the environment and retract axioms that may cause errors
    # obs = env.reset()
    # KB.retractall('stepping_on(agent,_,_)')

# %%
for episode in range(NUM_EPISODES):
    run(obs,performed_acts)
    


print(f'After {NUM_EPISODES} episodes, mean return is {sum(rewards)/NUM_EPISODES}')
print("The rewards of the episodes are:", rewards)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 for episode in range(NUM_EPISODES):
# ----> 2     run(obs,performed_acts)
#       6 print(f'After {NUM_EPISODES} episodes, mean return is {sum(rewards)/NUM_EPISODES}')
#       7 print("The rewards of the episodes are:", rewards)
#
# Cell In[5], line 123, in run(obs, performed_acts)
#     119         break
#     122 # Display game with interface
# --> 123 show_match(ep_states,0,600,250,1350)
#     124 # show_match(ep_states,0,200,0,200)
#     125 # Print information about the ended episode
#     126 print(f'Episode {episode} - {steps} steps')
#
# File ~/aif/utilsk.py:374, in show_match(states, x0, x1, y0, y1)
#     372 for state in states[1:]:
#     373     time.sleep(0.05)
# --> 374     display.display(plt.gcf())
#     375     display.clear_output(wait=True)
#     376     image.set_data(state[x0:x1, y0:y1])
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336     renderer = _get_renderer(
#    2337         self.figure,
#    2338         functools.partial(
#    2339             print_method, orientation=orientation)
#    2340     )
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342         self.figure.draw(renderer)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/figure.py:3175, in Figure.draw(self, renderer)
#    3172         # ValueError can occur when resizing a window.
#    3174 self.patch.draw(renderer)
# -> 3175 mimage._draw_list_compositing_images(
#    3176     renderer, self, artists, self.suppressComposite)
#    3178 for sfig in self.subfigs:
#    3179     sfig.draw(renderer)
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/axes/_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/patches.py:591, in Patch.draw(self, renderer)
#     589 tpath = transform.transform_path_non_affine(path)
#     590 affine = transform.get_affine()
# --> 591 self._draw_paths_with_artist_properties(
#     592     renderer,
#     593     [(tpath, affine,
#     594       # Work around a bug in the PDF and SVG renderers, which
#     595       # do not draw the hatches if the facecolor is fully
#     596       # transparent, but do if it is None.
#     597       self._facecolor if self._facecolor[3] else None)])
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/matplotlib/patches.py:553, in Patch._draw_paths_with_artist_properties(self, renderer, draw_path_args_list)
#     551     lw = 0
#     552 gc.set_linewidth(lw)
# --> 553 gc.set_dashes(*self._dash_pattern)
#     554 gc.set_capstyle(self._capstyle)
#     555 gc.set_joinstyle(self._joinstyle)
#
# KeyboardInterrupt:

# %%
performed_acts

# %%
env.render()
# Out:
#
#
#
#
#                     --------------------------------------
#                     |....................................|
#                     |..-----....|..|.............|.......|
#                     |..|   |..-------------...------.....|
#                     |..--- |....|..|.....................|
#                     |....| --......|-....-----......|....|
#                     |..<.|  |-------.........|......|....|
#                     |....|  |................|--..--|....|
#                     ------  --------....------......|....|
#                                    |................|..---
#                                    --------.........|....
#                                           --------  |....
#                                                  #@#-....
#                                                  ---|....
#                                                     -----
#
#
#
# Agent the Footpad              St:14 Dx:18 Co:17 In:9 Wi:8 Ch:9 Chaotic S:0
# Dlvl:1 $:0 HP:12(12) Pw:2(2) AC:7 Xp:1/0

# %%
obs, reward, done, info=perform_action("west", env, KB,obs)
plt.imshow(obs['pixel_crop'])

# %%
obs, reward, done, info = env.step(3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 obs, reward, done, info = env.step(3)
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/minihack/base.py:398, in MiniHack.step(self, action)
#     395 self._previous_action = action
#     396 # Within this call, _is_episode_end is called and then _reward_fn,
#     397 # both using self.reward_manager
# --> 398 return super().step(action)
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/nle/env/base.py:359, in NLE.step(self, action)
#     356 # Careful: By default we re-use Numpy arrays, so copy before!
#     357 last_observation = tuple(a.copy() for a in self.last_observation)
# --> 359 observation, done = self.nethack.step(self.actions[action])
#     360 is_game_over = observation[self._program_state_index][0] == 1
#     361 if is_game_over or not self._allow_all_modes:
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/nle/nethack/nethack.py:250, in Nethack.step(self, action)
#     249 def step(self, action):
# --> 250     self._pynethack.step(action)
#     251     return self._step_return(), self._pynethack.done()
#
# RuntimeError: Called step on finished NetHack

# %%
 bytes(obs['message']).decode('utf-8').rstrip('\x00')
# Out:
# "You can't move diagonally into an intact doorway."

# %%
for obj in obs['inv_strs']:
        obj = bytes(obj).decode('utf-8').rstrip('\x00')
        print(obj)
# Out:
# a +0 short sword (weapon in hand)
# 9 +0 daggers (alternate weapon; not wielded)
# an uncursed +1 leather armor (being worn)
# an uncursed potion of sickness
# an uncursed lock pick
# an empty uncursed sack

# %%
bytes(obs['inv_strs'][15][50]).decode('utf-8').rstrip('\x00')
# Out:
# ''

# %%
positions["door"], positions["agent"]
# Out:
# ((11, 28), (10, 28))

# %%
for i in range(21):
        for j in range(79):
            if not (obs['screen_descriptions'][i][j] == 0).all():
                obj = bytes(obs['screen_descriptions'][i][j]).decode('utf-8').rstrip('\x00')
                print(obj,obs["chars"][i][j],obs['glyphs'][i][j])

# %%
obj = bytes(obs['screen_descriptions'][i][j]).decode('utf-8').rstrip('\x00')
